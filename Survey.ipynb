# %% [markdown]
# <a href="https://colab.research.google.com/github/nbokadia/simple-python-mysql-connector/blob/main/Survey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/survey_results_public.csv', index_col = 'Respondent') #or use df.set_index('', inplace = True)
schema_df= pd.read_csv('/content/survey_results_schema.csv', index_col = 'Column')

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3088 entries, 1 to 3101
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    3088 non-null   object
#  1   Hobbyist                      3088 non-null   object
#  2   Age                           2709 non-null   float64
#  3   Age1stCode                    3065 non-null   object
#  4   CompFreq                      2294 non-null   object
#  5   CompTotal                     2138 non-null   float64
#  6   ConvertedComp                 2131 non-null   float64
#  7   Country                       3088 non-null   object
#  8   CurrencyDesc                  2563 non-null   object
#  9   CurrencySymbol                2563 non-null   object
#  10  DatabaseDesireNextYear        2331 non-null   object
#  11  DatabaseWorkedWith            2653 non-null   object
# ...

# %%
pd.set_option('display.max_columns',61)
pd.set_option('display.max_rows',61)

# %%
df.head(5)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
schema_df.sort_index(inplace=True)
schema_df.head()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# CompFreq        Is that compensation weekly, monthly, or yearly?
# CompTotal      What is your current total compensation (salar...
# ConvertedComp  Salary converted to annual USD salaries using ...

# %%
schema_df.loc['WelcomeChange','QuestionText']
# Out:
# 'Compared to last year, how welcome do you feel on Stack Overflow?'

# %%
df['Hobbyist'].value_counts()

df.loc[1:2, 'Hobbyist':'Employment']
# Out:
#            Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# Respondent
# 1               Yes  NaN         13  Monthly        NaN            NaN
# 2                No  NaN         19      NaN        NaN            NaN
#
#                    Country    CurrencyDesc CurrencySymbol  \
# Respondent
# 1                  Germany   European Euro            EUR
# 2           United Kingdom  Pound sterling            GBP
#
#            DatabaseDesireNextYear                         DatabaseWorkedWith  \
# Respondent
# 1            Microsoft SQL Server  Elasticsearch;Microsoft SQL Server;Oracle
# 2                             NaN                                        NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
#
#                                                     EdLevel  \
# Respondent
# ...

# %%
filt = (df['Hobbyist'] == 'Yes')

# %%
df[filt].head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 3              I code primarily as a hobby      Yes  NaN         15      NaN
#
#             CompTotal  ConvertedComp             Country   CurrencyDesc  \
# Respondent
# 1                 NaN            NaN             Germany  European Euro
# 3                 NaN            NaN  Russian Federation            NaN
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 3                     NaN                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 3                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
Countries = ['India','United States','Germany']
filt = df['Country'].isin(Countries)
filt1 = df['LanguageWorkedWith'].str.contains('Python', na= False)

# %%
df.loc[filt, 'Country']
# Out:
# Respondent
# 1             Germany
# 5       United States
# 6             Germany
# 7               India
# 8       United States
#             ...
# 3097    United States
# 3098    United States
# 3099    United States
# 3100    United States
# 3101    United States
# Name: Country, Length: 1796, dtype: object

# %%
df.loc[filt1, 'LanguageWorkedWith']
# Out:
# Respondent
# 3                                Objective-C;Python;Swift
# 8                                              Python;SQL
# 10                    HTML/CSS;Java;JavaScript;Python;SQL
# 13                                    C;JavaScript;Python
# 15       Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                               ...
# 3094    Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 3095    C#;HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 3097             HTML/CSS;Java;JavaScript;Python;Ruby;SQL
# 3098                              JavaScript;Python;R;SQL
# 3099    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# Name: LanguageWorkedWith, Length: 1357, dtype: object

# %%
df.rename(columns={'CurrencySymbol': 'Currency'}, inplace = True)

# %%
df['Currency']
# Out:
# Respondent
# 1       EUR
# 2       GBP
# 3       NaN
# 4       ALL
# 5       NaN
#        ...
# 3097    NaN
# 3098    USD
# 3099    USD
# 3100    USD
# 3101    USD
# Name: Currency, Length: 3088, dtype: object

# %%
df['Hobbyist'].apply(lambda x: x.lower())
df['Hobbyist'].apply(len)
#len(df['Hobbyist'])
# Out:
# Respondent
# 1       3
# 2       2
# 3       3
# 4       3
# 5       3
#        ..
# 3097    3
# 3098    3
# 3099    3
# 3100    3
# 3101    3
# Name: Hobbyist, Length: 3088, dtype: int64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1       Yes
# 2        No
# 3       Yes
# 4       Yes
# 5       Yes
#        ...
# 3097    Yes
# 3098    Yes
# 3099    Yes
# 3100    Yes
# 3101    Yes
# Name: Hobbyist, Length: 3088, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': 'True', 'No': 'False'})
df['Hobbyist']
# Out:
# Respondent
# 1        True
# 2       False
# 3        True
# 4        True
# 5        True
#         ...
# 3097     True
# 3098     True
# 3099     True
# 3100     True
# 3101     True
# Name: Hobbyist, Length: 3088, dtype: object

# %%
df['CurrencyDesc'].str.split(' ', expand=True)
#df[['con','curr','q','w','e']] == df['CurrencyDesc'].str.split(' ', expand=True)
# Out:
#                    0         1       2     3     4
# Respondent
# 1           European      Euro    None  None  None
# 2              Pound  sterling    None  None  None
# 3                NaN       NaN     NaN   NaN   NaN
# 4           Albanian       lek    None  None  None
# 5                NaN       NaN     NaN   NaN   NaN
# ...              ...       ...     ...   ...   ...
# 3097             NaN       NaN     NaN   NaN   NaN
# 3098          United    States  dollar  None  None
# 3099          United    States  dollar  None  None
# 3100          United    States  dollar  None  None
# 3101          United    States  dollar  None  None
#
# [3088 rows x 5 columns]

# %%
filt = df['Gender']=='Male'
filt1 = df['Gender']=='Female'

# %%
df.drop(index=1)
df.drop(index=df[filt].index, inplace=True)

# %%
df['Gender']
# Out:
# Respondent
# 1       Man
# 2       NaN
# 3       NaN
# 4       Man
# 5       Man
#        ...
# 3097    Man
# 3098    Man
# 3099    Man
# 3100    Man
# 3101    Man
# Name: Gender, Length: 3088, dtype: object

# %%
df.sort_values(by='Country', ascending=True)
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 2932                I am a developer by profession    False   NaN         14
# 898                 I am a developer by profession     True   NaN        NaN
# 4                   I am a developer by profession     True  25.0         18
# 564                 I am a developer by profession     True  22.0         18
# 2010        I am a student who is learning to code     True  24.0         18
# ...                                            ...      ...   ...        ...
# 2243        I am a student who is learning to code     True  19.0         16
# 657                 I am a developer by profession     True  21.0         17
# 822                 I am a developer by profession    False  20.0         18
# 2476                I am a developer by profession     True  30.0         15
# 826         I am a student who is learning to code     True   NaN         18
#
# ...

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 123     2000000.0
# 125     2000000.0
# 193     2000000.0
# 665     2000000.0
# 699     2000000.0
# 724     2000000.0
# 818     2000000.0
# 986     2000000.0
# 1022    2000000.0
# 1036    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 123                            I am a developer by profession     True  26.0
# 125         I am not primarily a developer, but I write co...     True  41.0
# 193                            I am a developer by profession     True  29.0
# 665                            I am a developer by profession     True  24.0
# 699         I am not primarily a developer, but I write co...     True  39.0
# 724         I am not primarily a developer, but I write co...     True   NaN
# 818         I am not primarily a developer, but I write co...     True  40.0
# 986                            I am a developer by profession     True  27.0
# 1022                           I am a developer by profession     True  34.0
# 1036                           I am a developer by profession     True  26.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# Respondent
# ...

# %%
df.describe()
# Out:
#                Age     CompTotal  ConvertedComp  WorkWeekHrs
# count  2709.000000  2.138000e+03   2.131000e+03  2446.000000
# mean     32.781211  4.677268e+45   1.453171e+05    40.923140
# std      10.557782  2.162699e+47   2.931814e+05    13.413436
# min      11.000000  0.000000e+00   0.000000e+00     4.000000
# 25%      25.000000  4.856250e+04   4.608950e+04    40.000000
# 50%      31.000000  8.500000e+04   8.107400e+04    40.000000
# 75%      38.000000  1.300000e+05   1.280000e+05    42.000000
# max      99.000000  1.000000e+49   2.000000e+06   375.000000

# %%
df['OpSys'].value_counts()
# Out:
# Windows        1502
# MacOS           844
# Linux-based     707
# BSD               3
# Name: OpSys, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United States                  1554
# Canada                          289
# United Kingdom                  166
# Germany                         125
# India                           117
#                                ...
# Haiti                             1
# Panama                            1
# United Republic of Tanzania       1
# Sudan                             1
# Singapore                         1
# Name: Country, Length: 98, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp['DatabaseWorkedWith'].value_counts().head(50)
# Out:
# Country      DatabaseWorkedWith
# Afghanistan  MongoDB;MySQL                                                                                                 1
# Albania      Oracle                                                                                                        1
# Algeria      MySQL;Oracle                                                                                                  1
#              MySQL;PostgreSQL                                                                                              1
#              MySQL;SQLite                                                                                                  1
# Argentina    Cassandra;Firebase;Microsoft SQL Server;MongoDB;MySQL;Oracle;PostgreSQL                                       1
#              DynamoDB;Elasticsearch;Firebase;MariaDB;MySQL;PostgreSQL;Redis                                                1
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
xlabel = 'Country'
ylabel = 'DatabaseWorkedWith'
# plt.plot(x='Country', y='DatabaseWorkedWith')
# plt.plot(xlabel, ylabel, label = 'linear', data =df) --not working
# plt.show()
# import numpy as np

# # Prepare the data
# x = np.linspace(0, 10, 100)

# # Plot the data
# plt.plot(x, x, label='linear')

# # Add a legend
# plt.legend()

# # Show the plot
# plt.show()

# %%
# to get the result in % format
country_grp['DatabaseWorkedWith'].value_counts(normalize = True).loc['India']
# Out:
# DatabaseWorkedWith
# MySQL                      0.115385
# Microsoft SQL Server       0.038462
# MongoDB;MySQL              0.038462
# MySQL;SQLite               0.038462
# Firebase                   0.028846
#                              ...
# MySQL;PostgreSQL;Redis     0.009615
# MySQL;PostgreSQL;SQLite    0.009615
# Oracle                     0.009615
# PostgreSQL;Redis           0.009615
# Redis                      0.009615
# Name: DatabaseWorkedWith, Length: 68, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 44

# %%
Country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_respondents = df['Country'].value_counts()

# %%
python_df = pd.concat([country_respondents, Country_uses_python], axis = 'columns', sort = False)
python_df
# Out:
#                              Country  LanguageWorkedWith
# United States                   1554                 743
# Canada                           289                 124
# United Kingdom                   166                  69
# Germany                          125                  56
# India                            117                  44
# ...                              ...                 ...
# Haiti                              1                   0
# Panama                             1                   0
# United Republic of Tanzania        1                   1
# Sudan                              1                   0
# Singapore                          1                   0
#
# [98 rows x 2 columns]

# %%
python_df.rename(columns={'Country':'NumRespond','LanguageWorkedWith': 'NumKnowsPthon'}, inplace=True)

# %%
python_df
# Out:
#                              NumRespond  NumKnowsPthon
# United States                      1554            743
# Canada                              289            124
# United Kingdom                      166             69
# Germany                             125             56
# India                               117             44
# ...                                 ...            ...
# Haiti                                 1              0
# Panama                                1              0
# United Republic of Tanzania           1              1
# Sudan                                 1              0
# Singapore                             1              0
#
# [98 rows x 2 columns]

# %%
python_df['PctknowsPy'] = (python_df['NumKnowsPthon']/python_df['NumRespond'])*100

# %%
python_df.sort_values(by='PctknowsPy', ascending=False).head(50)
# Out:
#                                       NumRespond  NumKnowsPthon  PctknowsPy
# Uganda                                         2              2  100.000000
# Algeria                                        3              3  100.000000
# United Republic of Tanzania                    1              1  100.000000
# Honduras                                       1              1  100.000000
# Republic of Moldova                            1              1  100.000000
# Syrian Arab Republic                           1              1  100.000000
# Luxembourg                                     1              1  100.000000
# Viet Nam                                       2              2  100.000000
# China                                          3              3  100.000000
# Sri Lanka                                      4              3   75.000000
# Estonia                                        3              2   66.666667
# ...
